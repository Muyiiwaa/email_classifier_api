# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from train import get_data, encode_dataset

data = get_data()
encode_data, encoder = encode_dataset(data.drop(columns=['is_churned']))

# %%
encode_data.columns
# Out:
# Index(['gender', 'age', 'country', 'subscription_type', 'listening_time',
#        'songs_played_per_day', 'skip_rate', 'device_type',
#        'ads_listened_per_week', 'offline_listening'],
#       dtype='object')

# %%
data.columns
# Out:
# Index(['user_id', 'gender', 'age', 'country', 'subscription_type',
#        'listening_time', 'songs_played_per_day', 'skip_rate', 'device_type',
#        'ads_listened_per_week', 'offline_listening', 'is_churned'],
#       dtype='object')

# %%
import pandas as pd
import joblib

# %%
split_scale(encode_data=encode_data)
# Out:
# (      gender  age  country  subscription_type  listening_time  \
#  3776       2   43        0                  0              96
#  801        2   57        3                  2             161
#  4522       2   52        4                  1              63
#  5964       2   34        1                  3              25
#  1940       0   26        7                  1             252
#  ...      ...  ...      ...                ...             ...
#  3141       2   21        6                  1             203
#  4730       0   29        7                  2             215
#  6529       0   18        1                  1              54
#  1832       0   48        3                  2             183
#  2719       2   26        0                  3             253
#
#        songs_played_per_day  skip_rate  device_type  ads_listened_per_week  \
#  3776                    38       0.57            1                      0
# ...

# %%
X_test
# Out:
#         gender       age   country  subscription_type  listening_time  \
# 0    -1.224279 -0.917223 -1.094790          -0.475405        0.647618
# 1    -1.224279 -0.447955 -1.530008           0.433881        0.659536
# 2     1.238233  1.194482  0.646081          -0.475405       -1.259378
# 3     0.006977  0.021313  1.516516          -0.475405       -0.854141
# 4     1.238233 -0.760801 -1.530008          -1.384692       -0.985247
# ...        ...       ...       ...                ...             ...
# 1995 -1.224279 -1.464702  1.516516           1.343168        0.611861
# 1996  1.238233 -1.464702  1.081299           0.433881       -1.688451
# 1997 -1.224279 -1.230068  1.516516          -0.475405        0.826398
# 1998 -1.224279 -1.308280  0.210863           1.343168       -0.615767
# 1999 -1.224279 -1.386491 -0.659573          -0.475405       -0.794548
#
#       songs_played_per_day  skip_rate  device_type  ads_listened_per_week  \
# ...

# %%
from train import split_scale_data

X_train, X_test, y_train, y_test = split_scale_data(X=encode_data,
                                                    y= data[['is_churned']])
# Out:
# error detail: The feature names should match those that were passed during fit.
# Feature names unseen at fit time:
# - is_churned
# Feature names seen at fit time, yet now missing:
# - ads_listened_per_week
# - age
# - country
# - device_type
# - gender
# - ...
